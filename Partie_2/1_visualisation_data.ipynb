# %% [markdown]
# <a name="data"></a>
# # Exploring the dataset
#
# <img src="assets/brain_ai.jpeg" alt="U-net Image" width="400"/>
#
# In this first chapter, you'll be working with 3D MRI brain scans from the public [Medical Segmentation Decathalon](https://decathlon-10.grand-challenge.org/) challenge project. This is an incredibly rich dataset that provides you with labels associated with each voxel inside a 3D representation of a patient's brain.

# %% [markdown]
# ### Import packages
# For this lab, you'll import some basic packages (`numpy`, `matplotlib` and `seaborn`) for reading (`nibabel`) and visualizing (`itk`, `itkwidgets`, `ipywidgets`) the data.

# %%
# Import all the necessary packages

import numpy as np
import nibabel as nib
import itk
import itkwidgets
from ipywidgets import interact, interactive, IntSlider, ToggleButtons
import matplotlib.pyplot as plt
import scipy.misc
from scipy import ndimage
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')

# %% [markdown]
# ### Loading images of the brain
# Run the next cell to grab a single 3D MRI brain scan

# %%
# Define the image path and load the data
image_path = "Task01_BrainTumour/imagesTr/BRATS_001.nii.gz"
image_nii = nib.load(image_path)
print(f'Type of the image {type(image_nii)}') # Nifti1
# Out:
# Type of the image <class 'nibabel.nifti1.Nifti1Image'>

# %% [markdown]
# ### Extract the data as a numpy array
# The method `get_fdata()` returns the voxels informations as a numpy array.

# %%
# Extract data as numpy ndarray
image_data = image_nii.get_fdata()
type(image_data)
# Out:
# numpy.ndarray

# %%
# Get the image shape and print it out
height, width, depth, channels = image_data.shape
print(f"The image object has the following dimensions: height: {height}, width:{width}, depth:{depth}, channels:{channels}")
# Out:
# The image object has the following dimensions: height: 240, width:240, depth:155, channels:4

# %% [markdown]
# As you can see these "image objects" are actually 4 dimensional! With the exploratory steps below you'll get a better sense of exactly what each of these dimensions represents.
#
# - Height: The number of rows in the volume, representing the vertical dimension.
# - Width: The number of columns in the volume, representing the horizontal dimension.
# - Depth: The number of slices or layers in the volume, representing the depth dimension.
# - Channels: The number of channels in each voxel of the volume, with each channel typically representing a different type of information (e.g., sequences for MRI).
#
# ### Visualize the data
# The "depth" listed above indicates that there are 155 slices through the brain in every image object.
# You can visualize a single slice by running the cell below.
# _Note that if the slice is one of the first or the last (`i` near 0 or 154), you won't find much information and the screen will be dark_
#
# Everytime you run the cell, a new slice will be randomly pick.
#
# You can select a specific slice by choosing a value for `i` from 0 to 154. You can also change which channel you're looking at by changing the `channel` variable.
#
# Keep in mind that you could just as easily look at slices of this image object along the height or width dimensions. If you wish to do so, just shift `i` to a different dimension in the `plt.imshow()` command below. Which slice direction looks the most interesting to you?

# %%
# Select random layer number
max_slice = 154
max_channel = 3
i = np.random.randint(0, max_slice)
# if you want to display a specific slice, just comment the line above and uncomment the line below !
# i = maxval // 2

# Define a channel to look at = specific MRI sequences
channel = np.random.randint(0, max_channel)
print(f"Plotting Layer {i} Channel {channel} of Image")
rotated_img = ndimage.rotate(image_data[:, :, i, channel], 90) 
plt.imshow(rotated_img, cmap='gray')
plt.axis('off');
# Out:
# Plotting Layer 57 Channel 1 of Image

# %% [markdown]
# ### Interactive exploration
# Another way to visualize this dataset is by using IPython Widgets to allow for an interactive exploration of the data.
#
# Run the next cell to explore across different layers of the data. Move the slider to explore different layers. Change the `channel` value to explore different channels. See if you can tell which layer corresponds to the top of the brain and which corresponds to the bottom!
#
# If you're feeling ambitious, try modifying the code below to slice along a different axis through the image object and look at other channels to see what you can discover!

# %%
# Define a function to visualize the data
def explore_3dimage(layer):
    # Variables
    channel = 2

# used to rotate image
    rotated_img = ndimage.rotate(image_data[:, :, layer, channel], 90) 
    plt.figure(figsize=(10, 5))
    plt.imshow(rotated_img, cmap='gray');
    plt.title('Explore slices of Brain MRI', fontsize=20)
    plt.axis('off')
    return layer

# Run the ipywidgets interact() function to explore the data
interact(explore_3dimage, layer=(0, image_data.shape[2] - 1));
# Out:
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…

# %% [markdown]
# ### Explore the data labels
# In this section, you'll read in a new dataset containing the labels for the MRI scan you loaded above.

# %%
# Define the data path and load the data
label_path = "Task01_BrainTumour/labelsTr/BRATS_001.nii.gz"
label_obj = nib.load(label_path)
type(label_obj)
# Out:
# nibabel.nifti1.Nifti1Image

# %% [markdown]
# ### Extract the data as a numpy array
# Run the next cell to extract the data labels using the `get_fdata()` method of the image object

# %%
# Extract data labels
label_array = label_obj.get_fdata()
type(label_array)
label_array.shape
# Out:
# (240, 240, 155)

# %%
# Extract and print out the shape of the labels data
height, width, depth = label_array.shape
print(f"Dimensions of labels data array height: {height}, width: {width}, depth: {depth}")
print(f'With the unique values: {np.unique(label_array)}')
print("""Corresponding to the following label categories: 
0: for normal 
1: for edema
2: for non-enhancing tumor 
3: for enhancing tumor""")
# Out:
# Dimensions of labels data array height: 240, width: 240, depth: 155
# With the unique values: [0. 1. 2. 3.]
# Corresponding to the following label categories:
# 0: for normal
# 1: for edema
# 2: for non-enhancing tumor
# 3: for enhancing tumor

# %% [markdown]
# ### Visualize the labels for a specific layer
# Run the next cell to visualize a single layer of the labeled data. The code below is set up to show a single layer and you can set `i` to any value from 0 to 154 to look at a different layer.
#
# Note that if you choose a layer near 0 or 154 there might not be much to look at in the images.

# %%
# Define a single layer for plotting
layer = 50
# Define a dictionary of class labels
classes_dict = {
    'Normal': 0.,
    'Edema': 1.,
    'Non-enhancing tumor': 2.,
    'Enhancing tumor': 3. 
}
# Set up for plotting
fig, ax = plt.subplots(nrows=1, ncols=4, figsize=(50, 30))
for i in range(4):
    img_label_str = list(classes_dict.keys())[i]
    img = label_array[:,:,layer]
    mask = np.where(img == classes_dict[img_label_str], 255, 0)
    rotated_mask = ndimage.rotate(mask, 90) 
    ax[i].imshow(rotated_mask)
    ax[i].set_title(f"Layer {layer} for {img_label_str}", fontsize=45)
    ax[i].axis('off')
plt.tight_layout()

# %% [markdown]
# ### Interactive visualization across layers
# As another way of looking at the data, run the code below to create a visualization where you can choose the class you want to look at by clicking a button to choose a particular label and scrolling across layers using the slider!

# %%
# Create button values
select_class = ToggleButtons(
    options=['Normal','Edema', 'Non-enhancing tumor', 'Enhancing tumor'],
    description='Select Class:',
    disabled=False,
    button_style='info', 
    
)
# Create layer slider
select_layer = IntSlider(min=0, max=154, description='Select Layer', continuous_update=False)

    
# Define a function for plotting images
def plot_image(seg_class, layer):
    print(f"Plotting {layer} Layer Label: {seg_class}")
    img_label = classes_dict[seg_class]
    mask = np.where(label_array[:,:,layer] == img_label, 255, 0)
    rotated_mask = ndimage.rotate(mask, 90) 
    plt.figure(figsize=(10,5))
    plt.imshow(rotated_mask, cmap='gray')
    plt.axis('off');

# Use the interactive() tool to create the visualization
interactive(plot_image, seg_class=select_class, layer=select_layer)
# Out:
# interactive(children=(ToggleButtons(button_style='info', description='Select Class:', options=('Normal', 'Edem…
